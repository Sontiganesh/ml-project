# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ipl.csv')

# %%
df.columns
# Out:
# Index(['mid', 'date', 'venue', 'bat_team', 'bowl_team', 'batsman', 'bowler',
#        'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
#        'non-striker', 'total'],
#       dtype='object')

# %%
df.shape
# Out:
# (76014, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76014 entries, 0 to 76013
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mid             76014 non-null  int64
#  1   date            76014 non-null  object
#  2   venue           76014 non-null  object
#  3   bat_team        76014 non-null  object
#  4   bowl_team       76014 non-null  object
#  5   batsman         76014 non-null  object
#  6   bowler          76014 non-null  object
#  7   runs            76014 non-null  int64
#  8   wickets         76014 non-null  int64
#  9   overs           76014 non-null  float64
#  10  runs_last_5     76014 non-null  int64
#  11  wickets_last_5  76014 non-null  int64
#  12  striker         76014 non-null  int64
#  13  non-striker     76014 non-null  int64
#  14  total           76014 non-null  int64
# dtypes: float64(1), int64(8), object(6)
# memory usage: 8.7+ MB

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    mid        date                  venue               bat_team
# 0    1  18-04-2008  M Chinnaswamy Stadium  Kolkata Knight Riders  \
# 1    1  18-04-2008  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2    1  18-04-2008  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3    1  18-04-2008  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4    1  18-04-2008  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                      bowl_team      batsman   bowler  runs  wickets  overs
# 0  Royal Challengers Bangalore   SC Ganguly  P Kumar     1        0    0.1  \
# 1  Royal Challengers Bangalore  BB McCullum  P Kumar     1        0    0.2
# 2  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.2
# 3  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.3
# 4  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.4
#
#    runs_last_5  wickets_last_5  striker  non-striker  total
# 0            1               0        0            0    222
# 1            1               0        0            0    222
# 2            2               0        0            0    222
# 3            2               0        0            0    222
# 4            2               0        0            0    222

# %%
df['runs'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          1
# 1          1
# 2          2
# 3          2
# 4          2
#         ...
# 76009    121
# 76010    127
# 76011    128
# 76012    129
# 76013    129
# Name: runs, Length: 76014, dtype: int64>

# %% [markdown]
# ###Data cleaning
#
# * Remove Unwanted columns
# * Keeping only consistent teams
# * Converting the column 'date' from string into datetime object

# %%
##removing unwanted columns
columns_to_remove = ['mid', 'venue', 'batsman', 'bowler', 'striker', 'non-striker']

print('Before removing unwanted columns: {}'.format(df.shape))
df.drop(labels=columns_to_remove, axis=1, inplace=True)
print('After removing unwanted columns: {}'.format(df.shape))
# Out:
# Before removing unwanted columns: (76014, 15)
# After removing unwanted columns: (76014, 9)

# %%
df.head()
# Out:
#          date               bat_team                    bowl_team  runs
# 0  18-04-2008  Kolkata Knight Riders  Royal Challengers Bangalore     1  \
# 1  18-04-2008  Kolkata Knight Riders  Royal Challengers Bangalore     1
# 2  18-04-2008  Kolkata Knight Riders  Royal Challengers Bangalore     2
# 3  18-04-2008  Kolkata Knight Riders  Royal Challengers Bangalore     2
# 4  18-04-2008  Kolkata Knight Riders  Royal Challengers Bangalore     2
#
#    wickets  overs  runs_last_5  wickets_last_5  total
# 0        0    0.1            1               0    222
# 1        0    0.2            1               0    222
# 2        0    0.2            2               0    222
# 3        0    0.3            2               0    222
# 4        0    0.4            2               0    222

# %%
df.index
# Out:
# RangeIndex(start=0, stop=76014, step=1)

# %%
df['bat_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Deccan Chargers', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions'], dtype=object)

# %%
consistent_teams = ['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
                    'Mumbai Indians', 'Kings XI Punjab', 'Royal Challengers Bangalore',
                    'Delhi Daredevils', 'Sunrisers Hyderabad']

# %%
# Keeping only consistent teams
print('Before removing inconsistent teams: {}'.format(df.shape))
df = df[(df['bat_team'].isin(consistent_teams)) & (df['bowl_team'].isin(consistent_teams))]
print('After removing inconsistent teams: {}'.format(df.shape))
# Out:
# Before removing inconsistent teams: (76014, 9)
# After removing inconsistent teams: (53811, 9)

# %%
df['bat_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Kings XI Punjab', 'Royal Challengers Bangalore',
#        'Delhi Daredevils', 'Sunrisers Hyderabad'], dtype=object)

# %%
# Removing the first 5 overs data in every match
print('Before removing first 5 overs data: {}'.format(df.shape))
df = df[df['overs']>=5.0]
print('After removing first 5 overs data: {}'.format(df.shape))
# Out:
# Before removing first 5 overs data: (53811, 9)
# After removing first 5 overs data: (40108, 9)

# %%
from datetime import datetime
print("Before converting 'date' column from string to datetime object: {}".format(type(df.iloc[0,0])))
df['date'] = df['date'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
print("After converting 'date' column from string to datetime object: {}".format(type(df.iloc[0,0])))
# Out:
# Before converting 'date' column from string to datetime object: <class 'str'>
# After converting 'date' column from string to datetime object: <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
# Converting categorical features using OneHotEncoding method
encoded_df = pd.get_dummies(data=df, columns=['bat_team', 'bowl_team'])
encoded_df.columns
# Out:
# Index(['date', 'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5',
#        'total', 'bat_team_Chennai Super Kings', 'bat_team_Delhi Daredevils',
#        'bat_team_Kings XI Punjab', 'bat_team_Kolkata Knight Riders',
#        'bat_team_Mumbai Indians', 'bat_team_Rajasthan Royals',
#        'bat_team_Royal Challengers Bangalore', 'bat_team_Sunrisers Hyderabad',
#        'bowl_team_Chennai Super Kings', 'bowl_team_Delhi Daredevils',
#        'bowl_team_Kings XI Punjab', 'bowl_team_Kolkata Knight Riders',
#        'bowl_team_Mumbai Indians', 'bowl_team_Rajasthan Royals',
#        'bowl_team_Royal Challengers Bangalore',
#        'bowl_team_Sunrisers Hyderabad'],
#       dtype='object')

# %%
# Rearranging the columns
encoded_df = encoded_df[['date', 'bat_team_Chennai Super Kings', 'bat_team_Delhi Daredevils', 'bat_team_Kings XI Punjab',
              'bat_team_Kolkata Knight Riders', 'bat_team_Mumbai Indians', 'bat_team_Rajasthan Royals',
              'bat_team_Royal Challengers Bangalore', 'bat_team_Sunrisers Hyderabad',
              'bowl_team_Chennai Super Kings', 'bowl_team_Delhi Daredevils', 'bowl_team_Kings XI Punjab',
              'bowl_team_Kolkata Knight Riders', 'bowl_team_Mumbai Indians', 'bowl_team_Rajasthan Royals',
              'bowl_team_Royal Challengers Bangalore', 'bowl_team_Sunrisers Hyderabad',
              'overs', 'runs', 'wickets', 'runs_last_5', 'wickets_last_5', 'total']]

# %%
# Converting categorical features using OneHotEncoding method
encoded_df = pd.get_dummies(data=df, columns=['bat_team', 'bowl_team'])
encoded_df.columns
# Splitting the data into train and test set
X_train = encoded_df.drop(labels='total', axis=1)[encoded_df['date'].dt.year <= 2016]
X_train
X_test = encoded_df.drop(labels='total', axis=1)[encoded_df['date'].dt.year >= 2017]

y_train = encoded_df[encoded_df['date'].dt.year <= 2016]['total'].values
y_test = encoded_df[encoded_df['date'].dt.year >= 2017]['total'].values

# Removing the 'date' column
X_train.drop(labels='date', axis=True, inplace=True)
X_test.drop(labels='date', axis=True, inplace=True)

print("Training set: {} and Test set: {}".format(X_train.shape, X_test.shape))
# Out:
# Training set: (37330, 21) and Test set: (2778, 21)

# %% [markdown]
# ##Model Building

# %%
X_train
# Out:
#        runs  wickets  overs  runs_last_5  wickets_last_5
# 32       61        0    5.1           59               0  \
# 33       61        1    5.2           59               1
# 34       61        1    5.3           59               1
# 35       61        1    5.4           59               1
# 36       61        1    5.5           58               1
# ...     ...      ...    ...          ...             ...
# 68857   194        7   19.2           54               4
# 68858   200        7   19.3           56               4
# 68859   201        7   19.4           56               4
# 68860   202        7   19.5           57               4
# 68861   208        7   19.6           62               4
#
#        bat_team_Chennai Super Kings  bat_team_Delhi Daredevils
# 32                            False                      False  \
# 33                            False                      False
# 34                            False                      False
# 35                            False                      False
# 36                            False                      False
# ...                             ...                        ...
# 68857                         False                      False
# 68858                         False                      False
# 68859                         False                      False
# 68860                         False                      False
# 68861                         False                      False
#
#        bat_team_Kings XI Punjab  bat_team_Kolkata Knight Riders
# 32                        False                            True  \
# 33                        False                            True
# 34                        False                            True
# 35                        False                            True
# 36                        False                            True
# ...                         ...                             ...
# 68857                     False                           False
# 68858                     False                           False
# 68859                     False                           False
# 68860                     False                           False
# 68861                     False                           False
#
#        bat_team_Mumbai Indians  ...  bat_team_Royal Challengers Bangalore
# 32                       False  ...                                 False  \
# 33                       False  ...                                 False
# 34                       False  ...                                 False
# 35                       False  ...                                 False
# 36                       False  ...                                 False
# ...                        ...  ...                                   ...
# 68857                    False  ...                                 False
# 68858                    False  ...                                 False
# 68859                    False  ...                                 False
# 68860                    False  ...                                 False
# 68861                    False  ...                                 False
#
#        bat_team_Sunrisers Hyderabad  bowl_team_Chennai Super Kings
# 32                            False                          False  \
# 33                            False                          False
# 34                            False                          False
# 35                            False                          False
# 36                            False                          False
# ...                             ...                            ...
# 68857                          True                          False
# 68858                          True                          False
# 68859                          True                          False
# 68860                          True                          False
# 68861                          True                          False
#
#        bowl_team_Delhi Daredevils  bowl_team_Kings XI Punjab
# 32                          False                      False  \
# 33                          False                      False
# 34                          False                      False
# 35                          False                      False
# 36                          False                      False
# ...                           ...                        ...
# 68857                       False                      False
# 68858                       False                      False
# 68859                       False                      False
# 68860                       False                      False
# 68861                       False                      False
#
#        bowl_team_Kolkata Knight Riders  bowl_team_Mumbai Indians
# 32                               False                     False  \
# 33                               False                     False
# 34                               False                     False
# 35                               False                     False
# 36                               False                     False
# ...                                ...                       ...
# 68857                            False                     False
# 68858                            False                     False
# 68859                            False                     False
# 68860                            False                     False
# 68861                            False                     False
#
#        bowl_team_Rajasthan Royals  bowl_team_Royal Challengers Bangalore
# 32                          False                                   True  \
# 33                          False                                   True
# 34                          False                                   True
# 35                          False                                   True
# 36                          False                                   True
# ...                           ...                                    ...
# 68857                       False                                   True
# 68858                       False                                   True
# 68859                       False                                   True
# 68860                       False                                   True
# 68861                       False                                   True
#
#        bowl_team_Sunrisers Hyderabad
# 32                             False
# 33                             False
# 34                             False
# 35                             False
# 36                             False
# ...                              ...
# 68857                          False
# 68858                          False
# 68859                          False
# 68860                          False
# 68861                          False
#
# [37330 rows x 21 columns]

# %%
X_test
# Out:
#        runs  wickets  overs  runs_last_5  wickets_last_5
# 68894    46        1    5.1           42               1  \
# 68895    50        1    5.2           46               1
# 68896    50        1    5.3           44               1
# 68897    54        1    5.4           48               1
# 68898    58        1    5.5           51               1
# ...     ...      ...    ...          ...             ...
# 75884   106        9   18.1           29               4
# 75885   107        9   18.2           29               4
# 75886   107        9   18.3           28               4
# 75887   107        9   18.4           24               4
# 75888   107       10   18.5           23               5
#
#        bat_team_Chennai Super Kings  bat_team_Delhi Daredevils
# 68894                         False                      False  \
# 68895                         False                      False
# 68896                         False                      False
# 68897                         False                      False
# 68898                         False                      False
# ...                             ...                        ...
# 75884                         False                      False
# 75885                         False                      False
# 75886                         False                      False
# 75887                         False                      False
# 75888                         False                      False
#
#        bat_team_Kings XI Punjab  bat_team_Kolkata Knight Riders
# 68894                     False                           False  \
# 68895                     False                           False
# 68896                     False                           False
# 68897                     False                           False
# 68898                     False                           False
# ...                         ...                             ...
# 75884                     False                            True
# 75885                     False                            True
# 75886                     False                            True
# 75887                     False                            True
# 75888                     False                            True
#
#        bat_team_Mumbai Indians  ...  bat_team_Royal Challengers Bangalore
# 68894                    False  ...                                 False  \
# 68895                    False  ...                                 False
# 68896                    False  ...                                 False
# 68897                    False  ...                                 False
# 68898                    False  ...                                 False
# ...                        ...  ...                                   ...
# 75884                    False  ...                                 False
# 75885                    False  ...                                 False
# 75886                    False  ...                                 False
# 75887                    False  ...                                 False
# 75888                    False  ...                                 False
#
#        bat_team_Sunrisers Hyderabad  bowl_team_Chennai Super Kings
# 68894                          True                          False  \
# 68895                          True                          False
# 68896                          True                          False
# 68897                          True                          False
# 68898                          True                          False
# ...                             ...                            ...
# 75884                         False                          False
# 75885                         False                          False
# 75886                         False                          False
# 75887                         False                          False
# 75888                         False                          False
#
#        bowl_team_Delhi Daredevils  bowl_team_Kings XI Punjab
# 68894                       False                      False  \
# 68895                       False                      False
# 68896                       False                      False
# 68897                       False                      False
# 68898                       False                      False
# ...                           ...                        ...
# 75884                       False                      False
# 75885                       False                      False
# 75886                       False                      False
# 75887                       False                      False
# 75888                       False                      False
#
#        bowl_team_Kolkata Knight Riders  bowl_team_Mumbai Indians
# 68894                            False                     False  \
# 68895                            False                     False
# 68896                            False                     False
# 68897                            False                     False
# 68898                            False                     False
# ...                                ...                       ...
# 75884                            False                      True
# 75885                            False                      True
# 75886                            False                      True
# 75887                            False                      True
# 75888                            False                      True
#
#        bowl_team_Rajasthan Royals  bowl_team_Royal Challengers Bangalore
# 68894                       False                                   True  \
# 68895                       False                                   True
# 68896                       False                                   True
# 68897                       False                                   True
# 68898                       False                                   True
# ...                           ...                                    ...
# 75884                       False                                  False
# 75885                       False                                  False
# 75886                       False                                  False
# 75887                       False                                  False
# 75888                       False                                  False
#
#        bowl_team_Sunrisers Hyderabad
# 68894                          False
# 68895                          False
# 68896                          False
# 68897                          False
# 68898                          False
# ...                              ...
# 75884                          False
# 75885                          False
# 75886                          False
# 75887                          False
# 75888                          False
#
# [2778 rows x 21 columns]

# %% [markdown]
# ###Linear Regression

# %%
# Linear Regression Model
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_linear = lr.predict(X_test)

# %% [markdown]
# ####Linear regression model evaluation

# %%
from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse, accuracy_score
print("---- Linear Regression - Model Evaluation ----")
print("Mean Absolute Error (MAE): {}".format(mae(y_test, y_pred_linear)))
print("Mean Squared Error (MSE): {}".format(mse(y_test, y_pred_linear)))
print("Root Mean Squared Error (RMSE): {}".format(np.sqrt(mse(y_test, y_pred_linear))))
# Out:
# ---- Linear Regression - Model Evaluation ----
# Mean Absolute Error (MAE): 12.11861754619324
# Mean Squared Error (MSE): 251.00792310417262
# Root Mean Squared Error (RMSE): 15.84322956673205

# %% [markdown]
# ##Decission Tree

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_dt = dt.predict(X_test)

# %% [markdown]
# ####Model evaluation

# %%
print("---- Decision Tree Regression - Model Evaluation ----")
print("Mean Absolute Error (MAE): {}".format(mae(y_test, y_pred_dt)))
print("Mean Squared Error (MSE): {}".format(mse(y_test, y_pred_dt)))
print("Root Mean Squared Error (RMSE): {}".format(np.sqrt(mse(y_test, y_pred_dt))))
# Out:
# ---- Decision Tree Regression - Model Evaluation ----
# Mean Absolute Error (MAE): 16.879769618430526
# Mean Squared Error (MSE): 514.2584593232541
# Root Mean Squared Error (RMSE): 22.67726745715308

# %% [markdown]
# ##Random Forests Model

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rfr = rfr.predict(X_test)

# %%
print("---- Random Forest Regression - Model Evaluation ----")
print("Mean Absolute Error (MAE): {}".format(mae(y_test, y_pred_rfr)))
print("Mean Squared Error (MSE): {}".format(mse(y_test, y_pred_rfr)))
print("Root Mean Squared Error (RMSE): {}".format(np.sqrt(mse(y_test, y_pred_rfr))))
# Out:
# ---- Random Forest Regression - Model Evaluation ----
# Mean Absolute Error (MAE): 13.791616690664748
# Mean Squared Error (MSE): 334.36979265119794
# Root Mean Squared Error (RMSE): 18.28578116054105

# %% [markdown]
# As , we see Linear regression performing Best among the three regressor models so we select Linear regresssion model for boosting its performance  using adaboost algorithm

# %% [markdown]
# ###AdaBoost

# %%
from sklearn.ensemble import AdaBoostRegressor
adb_regressor = AdaBoostRegressor(base_estimator=lr, n_estimators=100)
adb_regressor.fit(X_train, y_train)
# Out:
# c:\Users\Ganesh Sonti\OneDrive\Desktop\ml project\venv\Lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# AdaBoostRegressor(base_estimator=LinearRegression(), n_estimators=100)

# %%
# Predicting results
y_pred_adb = adb_regressor.predict(X_test)

# %% [markdown]
# ####Model Evaluation

# %%
print("---- AdaBoost Regression - Model Evaluation ----")
print("Mean Absolute Error (MAE): {}".format(mae(y_test, y_pred_adb)))
print("Mean Squared Error (MSE): {}".format(mse(y_test, y_pred_adb)))
print("Root Mean Squared Error (RMSE): {}".format(np.sqrt(mse(y_test, y_pred_adb))))
# Out:
# ---- AdaBoost Regression - Model Evaluation ----
# Mean Absolute Error (MAE): 12.111562264167842
# Mean Squared Error (MSE): 246.39134349492554
# Root Mean Squared Error (RMSE): 15.696857758638368

# %% [markdown]
# ###Manual Predictions
# * Model trained on the data from IPL Seasons 1 to 9 ie: (2008 to 2016)
# *  Model tested on data from IPL Season 10 ie: (2017)
# * Model predicts on furthr seasons data

# %%
def predict_score(batting_team='Chennai Super Kings', bowling_team='Mumbai Indians', overs=5.1, runs=50, wickets=0, runs_in_prev_5=50, wickets_in_prev_5=0):
  temp_array = list()

  # Batting Team
  if batting_team == 'Chennai Super Kings':
    temp_array = temp_array + [1,0,0,0,0,0,0,0]
  elif batting_team == 'Delhi Daredevils':
    temp_array = temp_array + [0,1,0,0,0,0,0,0]
  elif batting_team == 'Kings XI Punjab':
    temp_array = temp_array + [0,0,1,0,0,0,0,0]
  elif batting_team == 'Kolkata Knight Riders':
    temp_array = temp_array + [0,0,0,1,0,0,0,0]
  elif batting_team == 'Mumbai Indians':
    temp_array = temp_array + [0,0,0,0,1,0,0,0]
  elif batting_team == 'Rajasthan Royals':
    temp_array = temp_array + [0,0,0,0,0,1,0,0]
  elif batting_team == 'Royal Challengers Bangalore':
    temp_array = temp_array + [0,0,0,0,0,0,1,0]
  elif batting_team == 'Sunrisers Hyderabad':
    temp_array = temp_array + [0,0,0,0,0,0,0,1]

  # Bowling Team
  if bowling_team == 'Chennai Super Kings':
    temp_array = temp_array + [1,0,0,0,0,0,0,0]
  elif bowling_team == 'Delhi Daredevils':
    temp_array = temp_array + [0,1,0,0,0,0,0,0]
  elif bowling_team == 'Kings XI Punjab':
    temp_array = temp_array + [0,0,1,0,0,0,0,0]
  elif bowling_team == 'Kolkata Knight Riders':
    temp_array = temp_array + [0,0,0,1,0,0,0,0]
  elif bowling_team == 'Mumbai Indians':
    temp_array = temp_array + [0,0,0,0,1,0,0,0]
  elif bowling_team == 'Rajasthan Royals':
    temp_array = temp_array + [0,0,0,0,0,1,0,0]
  elif bowling_team == 'Royal Challengers Bangalore':
    temp_array = temp_array + [0,0,0,0,0,0,1,0]
  elif bowling_team == 'Sunrisers Hyderabad':
    temp_array = temp_array + [0,0,0,0,0,0,0,1]

  # Overs, Runs, Wickets, Runs_in_prev_5, Wickets_in_prev_5
  temp_array = temp_array + [overs, runs, wickets, runs_in_prev_5, wickets_in_prev_5]

  # Converting into numpy array
  temp_array = np.array([temp_array])

  # Prediction
  return int(lr.predict(temp_array)[0])

# %% [markdown]
# **Creating Report For EDA**

# %%
# %pip install sweetviz
# Out:
# Requirement already satisfied: sweetviz in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (2.1.4)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from sweetviz) (2.0.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from sweetviz) (1.24.2)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from sweetviz) (3.7.1)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from sweetviz) (4.65.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from sweetviz) (1.10.1)
# Collecting jinja2>=2.11.1
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Requirement already satisfied: importlib-resources>=1.2.0 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from sweetviz) (5.12.0)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.2-cp311-cp311-win_amd64.whl (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.3)
# Requirement already satisfied: colorama in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ganesh sonti\onedrive\desktop\ml project\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Installing collected packages: MarkupSafe, jinja2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.10.1
#     Uninstalling Jinja2-2.10.1:
#       Successfully uninstalled Jinja2-2.10.1
# Successfully installed MarkupSafe-2.1.2 jinja2-3.1.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
train = pd.DataFrame(X_train)

# %%
train
# Out:
#        runs  wickets  overs  runs_last_5  wickets_last_5
# 32       61        0    5.1           59               0  \
# 33       61        1    5.2           59               1
# 34       61        1    5.3           59               1
# 35       61        1    5.4           59               1
# 36       61        1    5.5           58               1
# ...     ...      ...    ...          ...             ...
# 68857   194        7   19.2           54               4
# 68858   200        7   19.3           56               4
# 68859   201        7   19.4           56               4
# 68860   202        7   19.5           57               4
# 68861   208        7   19.6           62               4
#
#        bat_team_Chennai Super Kings  bat_team_Delhi Daredevils
# 32                            False                      False  \
# 33                            False                      False
# 34                            False                      False
# 35                            False                      False
# 36                            False                      False
# ...                             ...                        ...
# 68857                         False                      False
# 68858                         False                      False
# 68859                         False                      False
# 68860                         False                      False
# 68861                         False                      False
#
#        bat_team_Kings XI Punjab  bat_team_Kolkata Knight Riders
# 32                        False                            True  \
# 33                        False                            True
# 34                        False                            True
# 35                        False                            True
# 36                        False                            True
# ...                         ...                             ...
# 68857                     False                           False
# 68858                     False                           False
# 68859                     False                           False
# 68860                     False                           False
# 68861                     False                           False
#
#        bat_team_Mumbai Indians  ...  bat_team_Royal Challengers Bangalore
# 32                       False  ...                                 False  \
# 33                       False  ...                                 False
# 34                       False  ...                                 False
# 35                       False  ...                                 False
# 36                       False  ...                                 False
# ...                        ...  ...                                   ...
# 68857                    False  ...                                 False
# 68858                    False  ...                                 False
# 68859                    False  ...                                 False
# 68860                    False  ...                                 False
# 68861                    False  ...                                 False
#
#        bat_team_Sunrisers Hyderabad  bowl_team_Chennai Super Kings
# 32                            False                          False  \
# 33                            False                          False
# 34                            False                          False
# 35                            False                          False
# 36                            False                          False
# ...                             ...                            ...
# 68857                          True                          False
# 68858                          True                          False
# 68859                          True                          False
# 68860                          True                          False
# 68861                          True                          False
#
#        bowl_team_Delhi Daredevils  bowl_team_Kings XI Punjab
# 32                          False                      False  \
# 33                          False                      False
# 34                          False                      False
# 35                          False                      False
# 36                          False                      False
# ...                           ...                        ...
# 68857                       False                      False
# 68858                       False                      False
# 68859                       False                      False
# 68860                       False                      False
# 68861                       False                      False
#
#        bowl_team_Kolkata Knight Riders  bowl_team_Mumbai Indians
# 32                               False                     False  \
# 33                               False                     False
# 34                               False                     False
# 35                               False                     False
# 36                               False                     False
# ...                                ...                       ...
# 68857                            False                     False
# 68858                            False                     False
# 68859                            False                     False
# 68860                            False                     False
# 68861                            False                     False
#
#        bowl_team_Rajasthan Royals  bowl_team_Royal Challengers Bangalore
# 32                          False                                   True  \
# 33                          False                                   True
# 34                          False                                   True
# 35                          False                                   True
# 36                          False                                   True
# ...                           ...                                    ...
# 68857                       False                                   True
# 68858                       False                                   True
# 68859                       False                                   True
# 68860                       False                                   True
# 68861                       False                                   True
#
#        bowl_team_Sunrisers Hyderabad
# 32                             False
# 33                             False
# 34                             False
# 35                             False
# 36                             False
# ...                              ...
# 68857                          False
# 68858                          False
# 68859                          False
# 68860                          False
# 68861                          False
#
# [37330 rows x 21 columns]

# %%
test = pd.DataFrame(X_test)

# %%
test[:5]
# Out:
#        runs  wickets  overs  runs_last_5  wickets_last_5
# 68894    46        1    5.1           42               1  \
# 68895    50        1    5.2           46               1
# 68896    50        1    5.3           44               1
# 68897    54        1    5.4           48               1
# 68898    58        1    5.5           51               1
#
#        bat_team_Chennai Super Kings  bat_team_Delhi Daredevils
# 68894                         False                      False  \
# 68895                         False                      False
# 68896                         False                      False
# 68897                         False                      False
# 68898                         False                      False
#
#        bat_team_Kings XI Punjab  bat_team_Kolkata Knight Riders
# 68894                     False                           False  \
# 68895                     False                           False
# 68896                     False                           False
# 68897                     False                           False
# 68898                     False                           False
#
#        bat_team_Mumbai Indians  ...  bat_team_Royal Challengers Bangalore
# 68894                    False  ...                                 False  \
# 68895                    False  ...                                 False
# 68896                    False  ...                                 False
# 68897                    False  ...                                 False
# 68898                    False  ...                                 False
#
#        bat_team_Sunrisers Hyderabad  bowl_team_Chennai Super Kings
# 68894                          True                          False  \
# 68895                          True                          False
# 68896                          True                          False
# 68897                          True                          False
# 68898                          True                          False
#
#        bowl_team_Delhi Daredevils  bowl_team_Kings XI Punjab
# 68894                       False                      False  \
# 68895                       False                      False
# 68896                       False                      False
# 68897                       False                      False
# 68898                       False                      False
#
#        bowl_team_Kolkata Knight Riders  bowl_team_Mumbai Indians
# 68894                            False                     False  \
# 68895                            False                     False
# 68896                            False                     False
# 68897                            False                     False
# 68898                            False                     False
#
#        bowl_team_Rajasthan Royals  bowl_team_Royal Challengers Bangalore
# 68894                       False                                   True  \
# 68895                       False                                   True
# 68896                       False                                   True
# 68897                       False                                   True
# 68898                       False                                   True
#
#        bowl_team_Sunrisers Hyderabad
# 68894                          False
# 68895                          False
# 68896                          False
# 68897                          False
# 68898                          False
#
# [5 rows x 21 columns]

# %%
#import sweetviz
#my_report = sweetviz.analyze(([encoded_df,"encoded_df"]), target_feat= "total")

# %%
#my_report.show_html('report.html')

# %%
# Creating a pickle file for the classifier
import pickle
filename = 'lr-model.pkl'
pickle.dump(lr, open(filename, 'wb'))
